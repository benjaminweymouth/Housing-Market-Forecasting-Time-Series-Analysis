# %% [markdown]
# # Canadian Housing Market Forecasting: Time Series Analysis & Modelling.
# Description:

# %%
import numpy as np
import pandas as pd
from pathlib import Path
# %matplotlib inline

import warnings
warnings.simplefilter(action='ignore', category=Warning)

# %% [markdown]
# # Data Ingestion and Data Cleaning
# Description:

# %%
#csv for mortgage rates chartered_bank_interest.csv
#ingest the csv 
#take all dates after 1975-01-01
#take only the column named 5-year Conventional mortgage
df_chartered_bank_i = pd.read_csv('../Resources/Datasets/chartered_bank_interest.csv', index_col="date", infer_datetime_format=True, parse_dates=True)
df_chartered_bank_i.head()
# Out:
#             Prime rate  1-year Conventional mortgage  \
# date
# 1967-04-05         NaN                           NaN
# 1967-04-12         NaN                           NaN
# 1967-04-19         NaN                           NaN
# 1967-04-26         NaN                           NaN
# 1967-05-03         NaN                           NaN
#
#             3-year Conventional mortgage  5-year Conventional mortgage  \
# date
# 1967-04-05                           NaN                           NaN
# 1967-04-12                           NaN                           NaN
# 1967-04-19                           NaN                           NaN
# 1967-04-26                           NaN                           NaN
# 1967-05-03                           NaN                           NaN
#
#             1-year GIC  3-year GIC  5-year GIC  5-year personal fixed term  \
# date
# 1967-04-05         NaN         NaN         NaN                         NaN
# 1967-04-12         NaN         NaN         NaN                         NaN
# 1967-04-19         NaN         NaN         NaN                         NaN
# 1967-04-26         NaN         NaN         NaN                         NaN
# 1967-05-03         NaN         NaN         NaN                         NaN
#
#             Daily Interest Savings (balances over $100,000)  \
# date
# 1967-04-05                                              NaN
# 1967-04-12                                              NaN
# 1967-04-19                                              NaN
# 1967-04-26                                              NaN
# 1967-05-03                                              NaN
#
#             Non-Chequable Savings Deposits
# date
# 1967-04-05                             4.5
# 1967-04-12                             4.5
# 1967-04-19                             4.5
# 1967-04-26                             4.5
# 1967-05-03                             4.5

# %%
#df_chartered_bank_i.index = df_chartered_bank_i.index.strftime('%d/%m/%Y')

# %%
#df_chartered_bank_i.tail()

# %%
# Convert daily data to monthly through the resample function
df_chartered_bank_i.index = pd.to_datetime(df_chartered_bank_i.index)
df_chartered_bank_i.resample('1Q').mean().tail()
# Out:
#             Prime rate  1-year Conventional mortgage  \
# date
# 2020-12-31        2.45                      3.090000
# 2021-03-31        2.45                      2.813077
# 2021-06-30        2.45                      2.790000
# 2021-09-30        2.45                      2.790000
# 2021-12-31        2.45                      2.790000
#
#             3-year Conventional mortgage  5-year Conventional mortgage  \
# date
# 2020-12-31                      3.556154                          4.79
# 2021-03-31                      3.490000                          4.79
# 2021-06-30                      3.490000                          4.79
# 2021-09-30                      3.490000                          4.79
# 2021-12-31                      3.490000                          4.79
#
#             1-year GIC  3-year GIC  5-year GIC  5-year personal fixed term  \
# date
# 2020-12-31    0.350000    0.600000    0.857692                    0.700000
# 2021-03-31    0.315385    0.530769    0.853846                    0.700000
# 2021-06-30    0.250000    0.553846    1.003846                    0.700000
# 2021-09-30    0.250000    0.600000    1.000000                    0.700000
# 2021-12-31    0.261111    0.616667    1.020000                    0.764444
#
#             Daily Interest Savings (balances over $100,000)  \
# date
# 2020-12-31                                             0.01
# 2021-03-31                                             0.01
# 2021-06-30                                             0.01
# 2021-09-30                                             0.01
# 2021-12-31                                             0.01
#
#             Non-Chequable Savings Deposits
# date
# 2020-12-31                            0.01
# 2021-03-31                            0.01
# 2021-06-30                            0.01
# 2021-09-30                            0.01
# 2021-12-31                            0.01

# %%
# Data ingestion - reading the CSV in from Statistics Canada and the Bank of Canada
# Credit liabilities of households.csv
# Residential mortgages 9+
df_Residential_mortgages = pd.read_csv('../Resources/Datasets/Credit liabilities of households date.csv')
df_Residential_mortgages.head()
# Out:
#        Date Non-mortgage loans Chartered banks 1 Personal loans 1 2  \
# 0  1/1/1990            121,607            77,976             31,781
# 1  2/1/1990            121,404            77,819             31,769
# 2  3/1/1990            122,358            78,386             31,878
# 3  4/1/1990            122,922            78,566             32,099
# 4  5/1/1990            123,435            78,941             32,316
#
#   Of which: Auto loans 1 2 Credit cards 1 2 Lines of credit 1 2 4  \
# 0                        0            9,090                 5,550
# 1                        0            8,768                 5,695
# 2                        0            8,728                 5,841
# 3                        0            8,883                 5,989
# 4                        0            9,050                 6,022
#
#   Lines of credit, of which: excluding home equity lines of credit 1 2  \
# 0                                              1,264
# 1                                              1,297
# 2                                              1,330
# 3                                              1,383
# 4                                              1,409
#
#   Other personal loans 1 2 Unincorporated business 1 2  ...  \
# 0                   16,523                      15,032  ...
# 1                   16,585                      15,002  ...
# 2                   16,828                      15,111  ...
# 3                   16,630                      14,965  ...
# 4                   16,699                      14,854  ...
#
#   Of which: real estate secured lending 14 Residential mortgages 14  \
# 0                                  235,302                  228,663
# 1                                  236,297                  229,555
# 2                                  238,489                  231,604
# 3                                  241,170                  234,168
# 4                                  243,796                  236,766
#
#   Chartered banks 10 14 Non-banks 10 14 Non-residential mortgages 14  \
# 0                85,704         142,959                        2,353
# 1                86,873         142,682                        2,344
# 2                87,830         143,774                        2,374
# 3                89,060         145,108                        2,396
# 4                90,473         146,293                        2,418
#
#   Chartered banks 13 14 Non-banks 13 14 Home equity lines of credit 14  \
# 0                   283           2,070                          4,286
# 1                   283           2,061                          4,398
# 2                   289           2,085                          4,511
# 3                   296           2,100                          4,606
# 4                   300           2,118                          4,612
#
#   Chartered banks 14 Non-banks 14 15
# 0              4,286               0
# 1              4,398               0
# 2              4,511               0
# 3              4,606               0
# 4              4,612               0
#
# [5 rows x 45 columns]

# %%
#df_Residential_mortgages.index = pd.to_datetime(df_Residential_mortgages.index)
#df_Residential_mortgages.resample('1Q').mean().tail()

# %%
df_Residential_mortgages = df_Residential_mortgages.sort_values(by = 'Date')
df_Residential_mortgages.head()
# Out:
#         Date Non-mortgage loans Chartered banks 1 Personal loans 1 2  \
# 0   1/1/1990            121,607            77,976             31,781
# 12  1/1/1991            126,815            82,095             31,969
# 24  1/1/1992            128,703            82,091             30,198
# 36  1/1/1993            129,776            82,922             28,744
# 48  1/1/1994            135,401            87,752             29,014
#
#    Of which: Auto loans 1 2 Credit cards 1 2 Lines of credit 1 2 4  \
# 0                         0            9,090                 5,550
# 12                        0           10,530                 6,732
# 24                        0           10,523                 8,219
# 36                        0           11,412                 9,267
# 48                        0           13,715                10,962
#
#    Lines of credit, of which: excluding home equity lines of credit 1 2  \
# 0                                               1,264
# 12                                              1,570
# 24                                              1,917
# 36                                              2,162
# 48                                              2,518
#
#    Other personal loans 1 2 Unincorporated business 1 2  ...  \
# 0                    16,523                      15,032  ...
# 12                   17,404                      15,460  ...
# 24                   17,807                      15,344  ...
# 36                   17,629                      15,870  ...
# 48                   18,274                      15,787  ...
#
#    Of which: real estate secured lending 14 Residential mortgages 14  \
# 0                                   235,302                  228,663
# 12                                  257,366                  249,678
# 24                                  278,356                  269,373
# 36                                  300,607                  290,695
# 48                                  315,577                  304,240
#
#    Chartered banks 10 14 Non-banks 10 14 Non-residential mortgages 14  \
# 0                 85,704         142,959                        2,353
# 12                97,401         152,277                        2,526
# 24               109,045         160,328                        2,682
# 36               126,953         163,742                        2,807
# 48               147,893         156,347                        2,893
#
#    Chartered banks 13 14 Non-banks 13 14 Home equity lines of credit 14  \
# 0                    283           2,070                          4,286
# 12                   319           2,207                          5,162
# 24                   365           2,317                          6,301
# 36                   483           2,324                          7,105
# 48                   615           2,278                          8,444
#
#    Chartered banks 14 Non-banks 14 15
# 0               4,286               0
# 12              5,162               0
# 24              6,301               0
# 36              7,105               0
# 48              8,444               0
#
# [5 rows x 45 columns]

# %%
#transpose 
#res_mortgage_transp = df_Residential_mortgages.T
#res_mortgage_transp.head()
df_Residential_mortgages = df_Residential_mortgages.set_index('Date')
df_Residential_mortgages.head()
# Out:
#          Non-mortgage loans Chartered banks 1 Personal loans 1 2  \
# Date
# 1/1/1990            121,607            77,976             31,781
# 1/1/1991            126,815            82,095             31,969
# 1/1/1992            128,703            82,091             30,198
# 1/1/1993            129,776            82,922             28,744
# 1/1/1994            135,401            87,752             29,014
#
#          Of which: Auto loans 1 2 Credit cards 1 2 Lines of credit 1 2 4  \
# Date
# 1/1/1990                        0            9,090                 5,550
# 1/1/1991                        0           10,530                 6,732
# 1/1/1992                        0           10,523                 8,219
# 1/1/1993                        0           11,412                 9,267
# 1/1/1994                        0           13,715                10,962
#
#          Lines of credit, of which: excluding home equity lines of credit 1 2  \
# Date
# 1/1/1990                                              1,264
# 1/1/1991                                              1,570
# 1/1/1992                                              1,917
# 1/1/1993                                              2,162
# 1/1/1994                                              2,518
#
#          Other personal loans 1 2 Unincorporated business 1 2 Non-banks 1  \
# Date
# 1/1/1990                   16,523                      15,032      43,631
# 1/1/1991                   17,404                      15,460      44,720
# 1/1/1992                   17,807                      15,344      46,612
# 1/1/1993                   17,629                      15,870      46,854
# 1/1/1994                   18,274                      15,787      47,649
#
#           ... Of which: real estate secured lending 14  \
# Date      ...
# 1/1/1990  ...                                  235,302
# 1/1/1991  ...                                  257,366
# 1/1/1992  ...                                  278,356
# 1/1/1993  ...                                  300,607
# 1/1/1994  ...                                  315,577
#
#          Residential mortgages 14 Chartered banks 10 14 Non-banks 10 14  \
# Date
# 1/1/1990                  228,663                85,704         142,959
# 1/1/1991                  249,678                97,401         152,277
# 1/1/1992                  269,373               109,045         160,328
# 1/1/1993                  290,695               126,953         163,742
# 1/1/1994                  304,240               147,893         156,347
#
#          Non-residential mortgages 14 Chartered banks 13 14 Non-banks 13 14  \
# Date
# 1/1/1990                        2,353                   283           2,070
# 1/1/1991                        2,526                   319           2,207
# 1/1/1992                        2,682                   365           2,317
# 1/1/1993                        2,807                   483           2,324
# 1/1/1994                        2,893                   615           2,278
#
#          Home equity lines of credit 14 Chartered banks 14 Non-banks 14 15
# Date
# 1/1/1990                          4,286              4,286               0
# 1/1/1991                          5,162              5,162               0
# 1/1/1992                          6,301              6,301               0
# 1/1/1993                          7,105              7,105               0
# 1/1/1994                          8,444              8,444               0
#
# [5 rows x 44 columns]

# %%
#df_Residential_mortgages = df_Residential_mortgages.sort_index().truncate(before='Residential mortgages 14', after='Residential mortgages 14', axis=1)

# %%
# Convert monthly data to quarterly through the resample function
#df_Residential_mortgages.index = pd.to_datetime(df_Residential_mortgages.index)
#df_Residential_mortgages.resample('1Q').mean().tail()

# %%
# Drop unwanted columns
df_Residential_mortgages = df_Residential_mortgages[['Residential mortgages 14']]
df_Residential_mortgages.head()
# Out:
#          Residential mortgages 14
# Date
# 1/1/1990                  228,663
# 1/1/1991                  249,678
# 1/1/1992                  269,373
# 1/1/1993                  290,695
# 1/1/1994                  304,240

# %%
# Reset index and change headers
#res_mortgage_transp = res_mortgage_transp.reset_index(drop=False)
#new_header = res_mortgage_transp.iloc[0] #grab the first row for the header
#res_mortgage_transp = res_mortgage_transp[1:] #take the data less the header row
#res_mortgage_transp.columns = new_header #set the header row as the dataframe header
#res_mortgage_transp.head()

# %%
#res_mortgage_transp.dtypes

# %%
#possible_formats = ['%b-y%', '%y-%b']
#res_mortgage_transp['Date'] = pd.to_datetime(res_mortgage_transp['Date'], errors='coerce', format=fmt) for fmt in possible_formats
#res_mortgage_transp['Date'] = res_mortgage_transp['Date'].dt.strftime('%m/%y')
#res_mortgage_transp['Date'].tail()
#start_date = '01-Jan'
#end_date = '21-Sep'

#res_mortgage_transp_mask_1 = (res_mortgage_transp['Date'] > start_date) & (res_mortgage_transp['Date'] <= end_date)
#res_mortgage_transp_mask_1.head()

# %%
# Reset date column as index and rename main column 
#df_Residential_mortgages = df_Residential_mortgages.set_index('Date')
df_Residential_mortgages = df_Residential_mortgages.rename(columns={'Residential mortgages 14': 'Residential Mortgages'})
df_Residential_mortgages.head()
# Out:
#          Residential Mortgages
# Date
# 1/1/1990               228,663
# 1/1/1991               249,678
# 1/1/1992               269,373
# 1/1/1993               290,695
# 1/1/1994               304,240

# %%
df_Residential_mortgages.dtypes
# Out:
# Residential Mortgages    object
# dtype: object

# %%
# Convert daily data to monthly through the resample function
df_Residential_mortgages.index = pd.to_datetime(df_Residential_mortgages.index)
df_Residential_mortgages_index = df_Residential_mortgages.resample('1Q').mean().head()
#df_Residential_mortgages.set_index(df_Residential_mortgages_index, inplace=True) 
#df_Residential_mortgages['date'] = df_Residential_mortgages_index
df_Residential_mortgages.head()


#res_mortgage_transp['Date'] = pd.to_datetime(res_mortgage_transp['Date'], format='%b-%y').add(pd.offsets.MonthEnd(0))
#res_mortgage_transp['Date'] = pd.to_datetime(res_mortgage_transp['Date'])
#df['end_date'] = pd.to_datetime(
#    df['end_date'], format='%b-%y'
#).add(pd.offsets.MonthEnd(0))
# Out:
#            Residential Mortgages
# Date
# 1990-01-01               228,663
# 1991-01-01               249,678
# 1992-01-01               269,373
# 1993-01-01               290,695
# 1994-01-01               304,240

# %%
df_Residential_mortgages.dtypes
# Out:
# Residential Mortgages    object
# dtype: object

# %%
#take the csv in 
#extract this column name: Credit liabilities of households 1 2 3
#extract this column name: Residential mortgages 9 
#flip the row into a column (transpose method)
#since the dates won't match, we need to add null values

# %%
# House afforability index 
df_House_afford_index  = pd.read_csv('../Resources/Datasets/AffordabilityIndex.csv')
df_House_afford_index.head()
# Out:
#      date  New housing price index  Housing Affordability Index
# 0  1980Q3                      NaN                        0.420
# 1  1980Q4                      NaN                        0.461
# 2  1981Q1                      NaN                        0.482
# 3  1981Q2                      NaN                        0.534
# 4  1981Q3                      NaN                        0.626
