# %% [markdown]
# ## Qualitative Analysis - taking Twitter articles on the Canadian Housing Market
#
# Use the Twitter APIv2 to pull the latest news articles for the Canadian Housing Market

# %%
import requests
import os
import json

# To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'
bearer_token = os.getenv("twitter_bearer_token")

search_url = "https://api.twitter.com/2/tweets/search/recent"
 

# Optional params: start_time,end_time,since_id,until_id,max_results,next_token,
# expansions,tweet.fields,media.fields,poll.fields,place.fields,user.fields
query_params = {'query': '("Canadian Housing Market") -"recent search" OR #twitterdev','tweet.fields': 'author_id'}

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r

def connect_to_endpoint(url, params):
    response = requests.get(url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()


def main():
    json_response = connect_to_endpoint(search_url, query_params)
    print(json.dumps(json_response, indent=4, sort_keys=True))


if __name__ == "__main__":
    main()
# Out:
# 200
# {
#     "data": [
#         {
#             "author_id": "702082289199611904",
#             "id": "1468307678334177282",
#             "text": "\ud83d\udd2ePeople always want to know the future...\n\n..We don't have a Delorean but we do have the  RE/MAX 2022 Canadian Housing Market Outlook Report\ud83d\udcc8\n\nREAD THIS ARTICLE to understand what we expect for 2022 in Ottawa real estate! \ud83d\udc47\n\nhttps://t.co/L6OEkvee7X\n\n#OttawaRealEstate https://t.co/vYuQfJMfQ3"
#         },
#         {
#             "author_id": "62561824",
#             "id": "1468292984072548358",
#             "text": "2022 Canadian #HousingMarket Outlook https://t.co/NAED898d99 #HomePrices to Increase 9.2% as Supply Shortages #RealEstate #property #listings #realtors #solds #HomeSales #NewListings #SupplyDemand #HomeOwnership #HomeSellers #HomeBuyers #InterestRates #mortgage #investment."
#         },
#         {
#             "author_id": "4757432175",
#             "id": "1468279026510929921",
#             "text": "RT remax \"49% of Canadians believe that the housing market will remain \ud83d\udc49steady\ud83d\udc48 next year according to the @REMAXca recent housing report. \nhttps://t.co/qnT1JWfvY3\""
#         },
#         {
#             "author_id": "67889596",
#             "id": "1468278601154011147",
#             "text": "#RT @remax: 49% of Canadians believe that the housing market will remain \ud83d\udc49steady\ud83d\udc48 next year according to the @REMAXca recent housing report. \nhttps://t.co/w2g7B5QsNJ"
#         },
#         {
#             "author_id": "47830616",
#             "id": "1468277798804541446",
#             "text": "49% of Canadians believe that the housing market will remain \ud83d\udc49steady\ud83d\udc48 next year according to the @REMAXca recent housing report. \nhttps://t.co/gQ2h4791ei"
#         },
#         {
#             "author_id": "57108290",
#             "id": "1468271634528223236",
#             "text": "Investors Remain Active in the Hot Canadian Housing Market\nhttps://t.co/eWOd2l9Jvh"
#         },
#         {
#             "author_id": "12470242",
#             "id": "1468270331261456388",
#             "text": "49% of Canadians believe that the housing market will remain \ud83d\udc49steady\ud83d\udc48 next year according to the @REMAXca recent housing report. \nhttps://t.co/Ke3aQPNDYf"
#         },
#         {
#             "author_id": "1467156140622446602",
#             "id": "1468246427952422927",
#             "text": "TWITTER API V2 LAUNCHING ONLINE EVENT IN BD\n\nSpeaker 1: \n@andypiper\n \nRegistration Link:  https://t.co/tgAvf6ZUa7\n\n@TwitterDev\n #community #twitterDev #twitterApi #BDTwitterDevCom\nJoin us: @BDTDevCom https://t.co/vfkSGAwG1Q"
#         },
#         {
#             "author_id": "786491",
#             "id": "1468244107114037264",
#             "text": "RT @sunnat629: TWITTER API V2 LAUNCHING ONLINE EVENT IN BD\n\nSpeaker 1: @andypiper \n\nRegistration Link:  https://t.co/bgkX2jd1R7\n\n @TwitterD\u2026"
#         },
#         {
#             "author_id": "385444088",
#             "id": "1468242654009909254",
#             "text": "RE/MAX 2022-CANADIAN HOUSING MARKET OUTLOOK\nhttps://t.co/ZgmdRnPU9n\n#canadianrealestate #ottawarealestateteam https://t.co/kirK9osmlW"
#         }
#     ],
#     "meta": {
#         "newest_id": "1468307678334177282",
#         "next_token": "b26v89c19zqg8o3fpdy8xj3qkdpxzxkpky1zeynmlxny5",
#         "oldest_id": "1468242654009909254",
#         "result_count": 10
#     }
# }

# %%
# import requests
# import os
# import json

# # To set your environment variables in your terminal run the following line:
# # export 'BEARER_TOKEN'='<your_bearer_token>'
# bearer_token = os.environ.get("BEARER_TOKEN")

# search_url = "https://api.twitter.com/2/tweets/search/all"

# # Optional params: start_time,end_time,since_id,until_id,max_results,next_token,
# # expansions,tweet.fields,media.fields,poll.fields,place.fields,user.fields
# query_params = {'query': '("Canada") OR #twitterdev','tweet.fields': 'author_id'}

# %%
# def bearer_oauth(r):
#     """
#     Method required by bearer token authentication.
#     """

#     r.headers["Authorization"] = f"Bearer {bearer_token}"
#     r.headers["User-Agent"] = "v2FullArchiveSearchPython"
#     return r


# def connect_to_endpoint(url, params):
#     response = requests.request("GET", search_url, auth=bearer_oauth, params=params)
#     print(response.status_code)
#     if response.status_code != 200:
#         raise Exception(response.status_code, response.text)
#     return response.json()


# def main():
#     json_response = connect_to_endpoint(search_url, query_params)
#     print(json.dumps(json_response, indent=4, sort_keys=True))


# if __name__ == "__main__":
#     main()
