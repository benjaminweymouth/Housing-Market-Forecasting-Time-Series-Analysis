# %% [markdown]
# # Canadian Housing Market Forecasting: Time Series Analysis & Modelling.
# Description:

# %%
import numpy as np
import pandas as pd
from pathlib import Path
# %matplotlib inline

import warnings
warnings.simplefilter(action='ignore', category=Warning)

# %% [markdown]
# # Data Ingestion and Data Cleaning
# Description:

# %%
#csv for mortgage rates chartered_bank_interest.csv
#ingest the csv 
#take all dates after 1975-01-01
#take only the column named 5-year Conventional mortgage
df_chartered_bank_i = pd.read_csv('../Resources/Datasets/chartered_bank_interest.csv', index_col="date", infer_datetime_format=True, parse_dates=True)
df_chartered_bank_i.head()
# Out:
#             Prime rate  1-year Conventional mortgage  \
# date
# 1967-04-05         NaN                           NaN
# 1967-04-12         NaN                           NaN
# 1967-04-19         NaN                           NaN
# 1967-04-26         NaN                           NaN
# 1967-05-03         NaN                           NaN
#
#             3-year Conventional mortgage  5-year Conventional mortgage  \
# date
# 1967-04-05                           NaN                           NaN
# 1967-04-12                           NaN                           NaN
# 1967-04-19                           NaN                           NaN
# 1967-04-26                           NaN                           NaN
# 1967-05-03                           NaN                           NaN
#
#             1-year GIC  3-year GIC  5-year GIC  5-year personal fixed term  \
# date
# 1967-04-05         NaN         NaN         NaN                         NaN
# 1967-04-12         NaN         NaN         NaN                         NaN
# 1967-04-19         NaN         NaN         NaN                         NaN
# 1967-04-26         NaN         NaN         NaN                         NaN
# 1967-05-03         NaN         NaN         NaN                         NaN
#
#             Daily Interest Savings (balances over $100,000)  \
# date
# 1967-04-05                                              NaN
# 1967-04-12                                              NaN
# 1967-04-19                                              NaN
# 1967-04-26                                              NaN
# 1967-05-03                                              NaN
#
#             Non-Chequable Savings Deposits
# date
# 1967-04-05                             4.5
# 1967-04-12                             4.5
# 1967-04-19                             4.5
# 1967-04-26                             4.5
# 1967-05-03                             4.5

# %%
# Convert daily data to monthly through the resample function
df_chartered_bank_i.index = pd.to_datetime(df_chartered_bank_i.index)
df_chartered_bank_i.resample('1Q').mean().tail()
# Out:
#             Prime rate  1-year Conventional mortgage  \
# date
# 2020-12-31        2.45                      3.090000
# 2021-03-31        2.45                      2.813077
# 2021-06-30        2.45                      2.790000
# 2021-09-30        2.45                      2.790000
# 2021-12-31        2.45                      2.790000
#
#             3-year Conventional mortgage  5-year Conventional mortgage  \
# date
# 2020-12-31                      3.556154                          4.79
# 2021-03-31                      3.490000                          4.79
# 2021-06-30                      3.490000                          4.79
# 2021-09-30                      3.490000                          4.79
# 2021-12-31                      3.490000                          4.79
#
#             1-year GIC  3-year GIC  5-year GIC  5-year personal fixed term  \
# date
# 2020-12-31    0.350000    0.600000    0.857692                    0.700000
# 2021-03-31    0.315385    0.530769    0.853846                    0.700000
# 2021-06-30    0.250000    0.553846    1.003846                    0.700000
# 2021-09-30    0.250000    0.600000    1.000000                    0.700000
# 2021-12-31    0.261111    0.616667    1.020000                    0.764444
#
#             Daily Interest Savings (balances over $100,000)  \
# date
# 2020-12-31                                             0.01
# 2021-03-31                                             0.01
# 2021-06-30                                             0.01
# 2021-09-30                                             0.01
# 2021-12-31                                             0.01
#
#             Non-Chequable Savings Deposits
# date
# 2020-12-31                            0.01
# 2021-03-31                            0.01
# 2021-06-30                            0.01
# 2021-09-30                            0.01
# 2021-12-31                            0.01

# %%
# Data ingestion - reading the CSV in from Statistics Canada and the Bank of Canada
# Credit liabilities of households.csv
# Residential mortgages 9+
df_Residential_mortgages = pd.read_csv('../Resources/Datasets/Credit liabilities of households.csv')
df_Residential_mortgages.head()
# Out:
#                        Date 1990-01-01 1990-02-01 1990-03-01 1990-04-01  \
# 0        Non-mortgage loans    121,607    121,404    122,358    122,922
# 1         Chartered banks 1     77,976     77,819     78,386     78,566
# 2        Personal loans 1 2     31,781     31,769     31,878     32,099
# 3  Of which: Auto loans 1 2          0          0          0          0
# 4          Credit cards 1 2      9,090      8,768      8,728      8,883
#
#   1990-05-01 1990-06-01 1990-07-01 1990-08-01 1990-09-01  ... 2020-12-01  \
# 0    123,435    124,132    124,492    124,806    125,752  ...    787,490
# 1     78,941     79,564     80,005     80,526     81,519  ...    575,885
# 2     32,316     32,539     32,687     32,805     32,854  ...    113,070
# 3          0          0          0          0          0  ...     90,763
# 4      9,050      9,232      9,310      9,516      9,788  ...     78,388
#
#   2021-01-01 2021-02-01 2021-03-01 2021-04-01 2021-05-01 2021-06-01  \
# 0    780,670    779,984    779,926    783,466    787,770    792,582
# 1    571,698    572,927    575,120    578,333    581,681    586,632
# 2    115,030    115,131    114,723    115,259    115,462    116,026
# 3     90,156     89,902     90,276     90,681     90,911     91,542
# 4     73,786     73,374     74,232     74,249     75,221     76,422
#
#   2021-07-01 2021-08-01 2021-09-01
# 0    793,265    798,152    802,793
# 1    587,778    591,617    595,916
# 2    116,245    116,837    117,381
# 3     91,917     92,298     92,252
# 4     77,223     78,335     79,324
#
# [5 rows x 382 columns]

# %%
#df_Residential_mortgages = df_Residential_mortgages.set_index('Date')
#df_Residential_mortgages.head()

# %%
#transpose 
res_mortgage_transp = df_Residential_mortgages.T
res_mortgage_transp.head()
# Out:
#                             0                  1                   2   \
# Date        Non-mortgage loans  Chartered banks 1  Personal loans 1 2
# 1990-01-01             121,607             77,976              31,781
# 1990-02-01             121,404             77,819              31,769
# 1990-03-01             122,358             78,386              31,878
# 1990-04-01             122,922             78,566              32,099
#
#                                   3                 4                      5   \
# Date        Of which: Auto loans 1 2  Credit cards 1 2  Lines of credit 1 2 4
# 1990-01-01                         0             9,090                  5,550
# 1990-02-01                         0             8,768                  5,695
# 1990-03-01                         0             8,728                  5,841
# 1990-04-01                         0             8,883                  5,989
#
#                                                            6   \
# Date        Lines of credit, of which: excluding home equi...
# 1990-01-01                                              1,264
# 1990-02-01                                              1,297
# 1990-03-01                                              1,330
# 1990-04-01                                              1,383
#
#                                   7                            8   \
# Date        Other personal loans 1 2  Unincorporated business 1 2
# 1990-01-01                    16,523                       15,032
# 1990-02-01                    16,585                       15,002
# 1990-03-01                    16,828                       15,111
# 1990-04-01                    16,630                       14,965
#
#                      9   ...                                        34  \
# Date        Non-banks 1  ...  Of which: real estate secured lending 14
# 1990-01-01       43,631  ...                                   235,302
# 1990-02-01       43,585  ...                                   236,297
# 1990-03-01       43,972  ...                                   238,489
# 1990-04-01       44,356  ...                                   241,170
#
#                                   35                     36               37  \
# Date        Residential mortgages 14  Chartered banks 10 14  Non-banks 10 14
# 1990-01-01                   228,663                 85,704          142,959
# 1990-02-01                   229,555                 86,873          142,682
# 1990-03-01                   231,604                 87,830          143,774
# 1990-04-01                   234,168                 89,060          145,108
#
#                                       38                     39  \
# Date        Non-residential mortgages 14  Chartered banks 13 14
# 1990-01-01                         2,353                    283
# 1990-02-01                         2,344                    283
# 1990-03-01                         2,374                    289
# 1990-04-01                         2,396                    296
#
#                          40                              41  \
# Date        Non-banks 13 14  Home equity lines of credit 14
# 1990-01-01            2,070                           4,286
# 1990-02-01            2,061                           4,398
# 1990-03-01            2,085                           4,511
# 1990-04-01            2,100                           4,606
#
#                             42               43
# Date        Chartered banks 14  Non-banks 14 15
# 1990-01-01               4,286                0
# 1990-02-01               4,398                0
# 1990-03-01               4,511                0
# 1990-04-01               4,606                0
#
# [5 rows x 44 columns]

# %%
res_mortgage_transp = res_mortgage_transp.truncate(before='35', after='35', axis=1)
res_mortgage_transp.head()
# Out:
#                                   35
# Date        Residential mortgages 14
# 1990-01-01                   228,663
# 1990-02-01                   229,555
# 1990-03-01                   231,604
# 1990-04-01                   234,168

# %%
# Reset index and change headers
res_mortgage_transp = res_mortgage_transp.reset_index(drop=False)
new_header = res_mortgage_transp.iloc[0] #grab the first row for the header
res_mortgage_transp = res_mortgage_transp[1:] #take the data less the header row
res_mortgage_transp.columns = new_header #set the header row as the dataframe header
res_mortgage_transp.head()
# Out:
# 0        Date Residential mortgages 14
# 1  1990-01-01                  228,663
# 2  1990-02-01                  229,555
# 3  1990-03-01                  231,604
# 4  1990-04-01                  234,168
# 5  1990-05-01                  236,766

# %%
res_mortgage_transp.dtypes
# Out:
# 0
# Date                        object
# Residential mortgages 14    object
# dtype: object

# %%
res_mortgage_transp['Date'] = res_mortgage_transp['Date'].astype('datetime64[ns]')

# %%
res_mortgage_transp.dtypes
# Out:
# 0
# Date                        datetime64[ns]
# Residential mortgages 14            object
# dtype: object

# %%
res_mortgage_transp['Residential mortgages 14'] = res_mortgage_transp['Residential mortgages 14'].astype(float)
res_mortgage_transp.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3712/3898420614.py in <module>
# ----> 1 res_mortgage_transp['Residential mortgages 14'] = res_mortgage_transp['Residential mortgages 14'].astype(float)
#       2 res_mortgage_transp.info()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1199     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1200         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1201         return arr.astype(dtype, copy=True)
#    1202
#    1203     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '228,663'

# %%
res_mortgage_transp.Date = pd.to_datetime(res_mortgage_transp.Date)
res_mortgage_transp.set_index('Date', inplace=True)

# %%
res_mortgage_transp.resample('1Q')

# %%
#res_mortgage_transp.index = pd.to_datetime(res_mortgage_transp.index)
res_mortgage_transp.resample('1Q', on='Date').mean()
res_mortgage_transp.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3712/3546615499.py in <module>
#       1 #res_mortgage_transp.index = pd.to_datetime(res_mortgage_transp.index)
# ----> 2 res_mortgage_transp.resample('1Q', on='Date').mean()
#       3 res_mortgage_transp.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#   10348         offset: TimedeltaConvertibleTypes | None = None,
#   10349     ) -> Resampler:
# > 10350         return super().resample(
#   10351             rule=rule,
#   10352             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8124
#    8125         axis = self._get_axis_number(axis)
# -> 8126         return get_resampler(
#    8127             self,
#    8128             freq=rule,
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in get_resampler(obj, kind, **kwds)
#    1380     """
#    1381     tg = TimeGrouper(**kwds)
# -> 1382     return tg._get_resampler(obj, kind=kind)
#    1383
#    1384
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1546
#    1547         """
# -> 1548         self._set_grouper(obj)
#    1549
#    1550         ax = self.ax
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in _set_grouper(self, obj, sort)
#     370             else:
#     371                 if key not in obj._info_axis:
# --> 372                     raise KeyError(f"The grouper name {key} is not found")
#     373                 ax = Index(obj[key], name=key)
#     374
#
# KeyError: 'The grouper name Date is not found'

# %%
# Reset date column as index and rename main column 
res_mortgage_transp = res_mortgage_transp.set_index('Date')
res_mortgage_transp = res_mortgage_transp.rename(columns={'Residential mortgages 14': 'Residential Mortgages'})
res_mortgage_transp.head()
# Out:
# 0          Residential Mortgages
# Date
# 1990-01-01               228,663
# 1990-02-01               229,555
# 1990-03-01               231,604
# 1990-04-01               234,168
# 1990-05-01               236,766

# %%
res_mortgage_transp.index = pd.to_datetime(res_mortgage_transp.index)
res_mortgage_transp.resample('1Q').mean().tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-09-30 00:00:00, 2020-12-31 00:00:00, 2021-03-31 00:00:00, 2021-06-30 00:00:00, 2021-09-30 00:00:00]

# %%
#res_mortgage_transp = res_mortgage_transp.set_index('Date')
#res_mortgage_transp.head()

# %%
#df_Residential_mortgages = df_Residential_mortgages.sort_index()
#df_Residential_mortgages.head()

# %%
# Drop unwanted columns
df_Residential_mortgages = df_Residential_mortgages[['Residential mortgages 14']]
df_Residential_mortgages.tail()
# Out:
#            Residential mortgages 14
# Date
# 2021-05-01                1,706,049
# 2021-06-01                1,730,211
# 2021-07-01                1,745,650
# 2021-08-01                1,760,664
# 2021-09-01                1,772,201

# %%
df_Residential_mortgages.index = pd.to_datetime(df_Residential_mortgages.index)
df_Residential_mortgages.resample('1Q').mean().tail()
# Out:
#             Government 9 10  Government 9 13  \
# Date
# 2020-09-30       462.666667       455.000000
# 2020-12-31       465.666667       451.000000
# 2021-03-31       467.666667       452.666667
# 2021-06-30       468.666667       452.333333
# 2021-09-30       478.333333       442.000000
#
#             Of which: financial vehicle corporations engaged in securitization 6 9 13  \
# Date
# 2020-09-30                                          94.000000
# 2020-12-31                                          84.666667
# 2021-03-31                                          81.666667
# 2021-06-30                                          81.333333
# 2021-09-30                                          82.000000
#
#             Other lenders n.e.i. 8 9 13
# Date
# 2020-09-30                   853.000000
# 2020-12-31                   849.333333
# 2021-03-31                   850.000000
# 2021-06-30                   859.000000
# 2021-09-30                   869.000000

# %%
# Convert monthly data to quarterly through the resample function
#df_Residential_mortgages.index = pd.to_datetime(df_Residential_mortgages.index)
#df_Residential_mortgages.resample('1Q').mean().tail()

# %%
# Drop unwanted columns
#df_Residential_mortgages = df_Residential_mortgages[['Residential mortgages 14']]
#df_Residential_mortgages.head()
# Out:
#            Residential mortgages 14
# Date
# 1990-01-01                  228,663
# 1990-02-01                  229,555
# 1990-03-01                  231,604
# 1990-04-01                  234,168
# 1990-05-01                  236,766

# %%
#res_mortgage_transp.dtypes

# %%
#possible_formats = ['%b-y%', '%y-%b']
#res_mortgage_transp['Date'] = pd.to_datetime(res_mortgage_transp['Date'], errors='coerce', format=fmt) for fmt in possible_formats
#res_mortgage_transp['Date'] = res_mortgage_transp['Date'].dt.strftime('%m/%y')
#res_mortgage_transp['Date'].tail()
#start_date = '01-Jan'
#end_date = '21-Sep'

#res_mortgage_transp_mask_1 = (res_mortgage_transp['Date'] > start_date) & (res_mortgage_transp['Date'] <= end_date)
#res_mortgage_transp_mask_1.head()

# %%
# Out:
#            Residential Mortgages
# Date
# 1990-01-01               228,663
# 1990-02-01               229,555
# 1990-03-01               231,604
# 1990-04-01               234,168
# 1990-05-01               236,766

# %%
df_Residential_mortgages.dtypes
# Out:
# Residential Mortgages    object
# dtype: object

# %%
# Convert daily data to monthly through the resample function
df_Residential_mortgages.index = pd.to_datetime(df_Residential_mortgages.index)
df_Residential_mortgages_index = df_Residential_mortgages.resample('1Q').mean().head()
#df_Residential_mortgages.set_index(df_Residential_mortgages_index, inplace=True) 
#df_Residential_mortgages['date'] = df_Residential_mortgages_index
df_Residential_mortgages.head()


#res_mortgage_transp['Date'] = pd.to_datetime(res_mortgage_transp['Date'], format='%b-%y').add(pd.offsets.MonthEnd(0))
#res_mortgage_transp['Date'] = pd.to_datetime(res_mortgage_transp['Date'])
#df['end_date'] = pd.to_datetime(
#    df['end_date'], format='%b-%y'
#).add(pd.offsets.MonthEnd(0))
# Out:
#            Residential Mortgages
# Date
# 1990-01-01               228,663
# 1990-02-01               229,555
# 1990-03-01               231,604
# 1990-04-01               234,168
# 1990-05-01               236,766

# %%
df_Residential_mortgages.dtypes
# Out:
# Residential Mortgages    object
# dtype: object

# %%
#take the csv in 
#extract this column name: Credit liabilities of households 1 2 3
#extract this column name: Residential mortgages 9 
#flip the row into a column (transpose method)
#since the dates won't match, we need to add null values

# %%
# House afforability index 
df_House_afford_index  = pd.read_csv('../Resources/Datasets/AffordabilityIndex.csv')
df_House_afford_index.head()
# Out:
#      date  New housing price index  Housing Affordability Index
# 0  1980Q3                      NaN                        0.420
# 1  1980Q4                      NaN                        0.461
# 2  1981Q1                      NaN                        0.482
# 3  1981Q2                      NaN                        0.534
# 4  1981Q3                      NaN                        0.626
